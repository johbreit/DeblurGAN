# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python test.py --dataroot "C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/blur_2" --model test --dataset_mode single --learn_residual
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/blur_2
# dataset_mode: single
# display_id: 1
# display_port: 8097
# display_single_pane_ncols: 0
# display_winsize: 256
# fineSize: 256
# gan_type: wgan-gp
# gpu_ids: [0]
# how_many: 5000
# input_nc: 3
# isTrain: False
# learn_residual: True
# loadSizeX: 640
# loadSizeY: 360
# max_dataset_size: inf
# model: test
# nThreads: 2
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# no_dropout: False
# no_flip: False
# norm: instance
# ntest: inf
# output_nc: 3
# phase: test
# resize_or_crop: resize_and_crop
# results_dir: ./results/
# serial_batches: False
# which_direction: AtoB
# which_epoch: latest
# which_model_netD: basic
# which_model_netG: resnet_9blocks
# -------------- End ----------------
# Opt.nThreads =  1
# dataset [SingleImageDataset] was created
# CustomDatasetDataLoader
# ...

# %%
# !python datasets/combine_A_and_B.py --fold_A "C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/blur" --fold_B "C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/sharp" --fold_AB "C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data"
# Out:
# [fold_A] =  C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/blur
# [fold_B] =  C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/sharp
# [fold_AB] =  C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data
# [num_imgs] =  1000000
# [use_AB] =  False
# Traceback (most recent call last):
#   File "datasets/combine_A_and_B.py", line 23, in <module>
#     img_list = os.listdir(img_fold_A)
# NotADirectoryError: [WinError 267] Der Verzeichnisname ist ungültig: 'C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/blur\\(0).PNG'

# %%
# !python train.py --dataroot "C:/Users/JBreitenbach/Documents/21_Sommersemester/01_Master-Thesis/03_Data/train_data" --learn_residual --resize_or_crop crop --fineSize 256
# Out:
# ^C

# %%
# !python -V
# Out:
# Python 3.7.10
